# %%
import pandas as pd

# %%
df_powers=pd.read_csv('superhero_powers.csv')
df_dc=pd.read_excel('superhero_info.xlsx', sheet_name="DC Comics")
df_marvel=pd.read_excel('superhero_info.xlsx', sheet_name="Marvel Comics")

# %%
df_dc.head(n=1)
# Out:
#        name Gender Eye color     Race Hair color  Height  Publisher Alignment  \
# 0  Abin Sur   Male      blue  Ungaran    No Hair     185  DC Comics      good
#
#    Weight
# 0    90.0

# %%
df_dc.tail()
# Out:
#              name  Gender Eye color      Race Hair color  Height  Publisher  \
# 210      Wildfire    Male         -         -          -     -99  DC Comics
# 211   Wonder Girl  Female      blue  Demi-God      Blond     165  DC Comics
# 212  Wonder Woman  Female      blue    Amazon      Black     183  DC Comics
# 213       Zatanna  Female      blue     Human      Black     170  DC Comics
# 214          Zoom    Male       red         -      Brown     185  DC Comics
#
#     Alignment  Weight
# 210      good     NaN
# 211      good    51.0
# 212      good    74.0
# 213      good    57.0
# 214       bad    81.0

# %%
df_dc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        215 non-null    object
#  1   Gender      215 non-null    object
#  2   Eye color   215 non-null    object
#  3   Race        215 non-null    object
#  4   Hair color  215 non-null    object
#  5   Height      215 non-null    int64
#  6   Publisher   215 non-null    object
#  7   Alignment   215 non-null    object
#  8   Weight      144 non-null    float64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 15.2+ KB

# %%
df_powers.info() # No col info show by default
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Columns: 168 entries, hero_names to Omniscient
# dtypes: bool(167), object(1)
# memory usage: 114.1+ KB

# %%
df_powers.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 168 columns):
#  #    Column                        Dtype
# ---   ------                        -----
#  0    hero_names                    object
#  1    Agility                       bool
#  2    Accelerated Healing           bool
#  3    Lantern Power Ring            bool
#  4    Dimensional Awareness         bool
#  5    Cold Resistance               bool
#  6    Durability                    bool
#  7    Stealth                       bool
#  8    Energy Absorption             bool
#  9    Flight                        bool
#  10   Danger Sense                  bool
#  11   Underwater breathing          bool
#  12   Marksmanship                  bool
#  13   Weapons Master                bool
#  14   Power Augmentation            bool
#  15   Animal Attributes             bool
#  16   Longevity                     bool
#  17   Intelligence                  bool
#  18   Super Strength                bool
#  19   Cryokinesis                   bool
#  20   Telepathy                     bool
#  21   Energy Armor                  bool
#  22   Energy Blasts                 bool
#  23   Duplication                   bool
#  24   Size Changing                 bool
#  25   Density Control               bool
#  26   Stamina                       bool
#  27   Astral Travel                 bool
#  28   Audio Control                 bool
#  29   Dexterity                     bool
#  30   Omnitrix                      bool
#  31   Super Speed                   bool
#  32   Possession                    bool
#  33   Animal Oriented Powers        bool
#  34   Weapon-based Powers           bool
#  35   Electrokinesis                bool
#  36   Darkforce Manipulation        bool
#  37   Death Touch                   bool
#  38   Teleportation                 bool
#  39   Enhanced Senses               bool
#  40   Telekinesis                   bool
#  41   Energy Beams                  bool
#  42   Magic                         bool
#  43   Hyperkinesis                  bool
#  44   Jump                          bool
#  45   Clairvoyance                  bool
#  46   Dimensional Travel            bool
#  47   Power Sense                   bool
#  48   Shapeshifting                 bool
#  49   Peak Human Condition          bool
#  50   Immortality                   bool
#  51   Camouflage                    bool
#  52   Element Control               bool
#  53   Phasing                       bool
#  54   Astral Projection             bool
#  55   Electrical Transport          bool
#  56   Fire Control                  bool
#  57   Projection                    bool
#  58   Summoning                     bool
#  59   Enhanced Memory               bool
#  60   Reflexes                      bool
#  61   Invulnerability               bool
#  62   Energy Constructs             bool
#  63   Force Fields                  bool
#  64   Self-Sustenance               bool
#  65   Anti-Gravity                  bool
#  66   Empathy                       bool
#  67   Power Nullifier               bool
#  68   Radiation Control             bool
#  69   Psionic Powers                bool
#  70   Elasticity                    bool
#  71   Substance Secretion           bool
#  72   Elemental Transmogrification  bool
#  73   Technopath/Cyberpath          bool
#  74   Photographic Reflexes         bool
#  75   Seismic Power                 bool
#  76   Animation                     bool
#  77   Precognition                  bool
#  78   Mind Control                  bool
#  79   Fire Resistance               bool
#  80   Power Absorption              bool
#  81   Enhanced Hearing              bool
#  82   Nova Force                    bool
#  83   Insanity                      bool
#  84   Hypnokinesis                  bool
#  85   Animal Control                bool
#  86   Natural Armor                 bool
#  87   Intangibility                 bool
#  88   Enhanced Sight                bool
#  89   Molecular Manipulation        bool
#  90   Heat Generation               bool
#  91   Adaptation                    bool
#  92   Gliding                       bool
#  93   Power Suit                    bool
#  94   Mind Blast                    bool
#  95   Probability Manipulation      bool
#  96   Gravity Control               bool
#  97   Regeneration                  bool
#  98   Light Control                 bool
#  99   Echolocation                  bool
#  100  Levitation                    bool
#  101  Toxin and Disease Control     bool
#  102  Banish                        bool
#  103  Energy Manipulation           bool
#  104  Heat Resistance               bool
#  105  Natural Weapons               bool
#  106  Time Travel                   bool
#  107  Enhanced Smell                bool
#  108  Illusions                     bool
#  109  Thirstokinesis                bool
#  110  Hair Manipulation             bool
#  111  Illumination                  bool
#  112  Omnipotent                    bool
#  113  Cloaking                      bool
#  114  Changing Armor                bool
#  115  Power Cosmic                  bool
#  116  Biokinesis                    bool
#  117  Water Control                 bool
#  118  Radiation Immunity            bool
#  119  Vision - Telescopic           bool
#  120  Toxin and Disease Resistance  bool
#  121  Spatial Awareness             bool
#  122  Energy Resistance             bool
#  123  Telepathy Resistance          bool
#  124  Molecular Combustion          bool
#  125  Omnilingualism                bool
#  126  Portal Creation               bool
#  127  Magnetism                     bool
#  128  Mind Control Resistance       bool
#  129  Plant Control                 bool
#  130  Sonar                         bool
#  131  Sonic Scream                  bool
#  132  Time Manipulation             bool
#  133  Enhanced Touch                bool
#  134  Magic Resistance              bool
#  135  Invisibility                  bool
#  136  Sub-Mariner                   bool
#  137  Radiation Absorption          bool
#  138  Intuitive aptitude            bool
#  139  Vision - Microscopic          bool
#  140  Melting                       bool
#  141  Wind Control                  bool
#  142  Super Breath                  bool
#  143  Wallcrawling                  bool
#  144  Vision - Night                bool
#  145  Vision - Infrared             bool
#  146  Grim Reaping                  bool
#  147  Matter Absorption             bool
#  148  The Force                     bool
#  149  Resurrection                  bool
#  150  Terrakinesis                  bool
#  151  Vision - Heat                 bool
#  152  Vitakinesis                   bool
#  153  Radar Sense                   bool
#  154  Qwardian Power Ring           bool
#  155  Weather Control               bool
#  156  Vision - X-Ray                bool
#  157  Vision - Thermal              bool
#  158  Web Creation                  bool
#  159  Reality Warping               bool
#  160  Odin Force                    bool
#  161  Symbiote Costume              bool
#  162  Speed Force                   bool
#  163  Phoenix Force                 bool
#  164  Molecular Dissipation         bool
#  165  Vision - Cryo                 bool
#  166  Omnipresent                   bool
#  167  Omniscient                    bool
# dtypes: bool(167), object(1)
# memory usage: 114.1+ KB

# %%
df_powers.columns
# Out:
# Index(['hero_names', 'Agility', 'Accelerated Healing', 'Lantern Power Ring',
#        'Dimensional Awareness', 'Cold Resistance', 'Durability', 'Stealth',
#        'Energy Absorption', 'Flight',
#        ...
#        'Web Creation', 'Reality Warping', 'Odin Force', 'Symbiote Costume',
#        'Speed Force', 'Phoenix Force', 'Molecular Dissipation',
#        'Vision - Cryo', 'Omnipresent', 'Omniscient'],
#       dtype='object', length=168)

# %%
df_powers.shape  # cols and rows

"""
PANDAS DATA TYPES (dtypes)
* All col must have same data type
* Comes from NumPy + extensions

"""
# Out:
# '\nPANDAS DATA TYPES (dtypes)\n* All col must have same data type\n* Comes from NumPy + extensions\n\n'

# %%
# to_numeric
# to_datetime
# you can specify the dtype of col on read_*
df_w=pd.read_csv("weather.csv")
df_w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              5 non-null      object
#  1   temperature_high  5 non-null      float64
#  2   temperature_low   5 non-null      object
#  3   rained            5 non-null      int64
#  4   snowed            5 non-null      bool
#  5   overcast          5 non-null      object
#  6   comments          5 non-null      object
# dtypes: bool(1), float64(1), int64(1), object(4)
# memory usage: 373.0+ bytes

# %%
df_w.dtypes
# Out:
# date                 object
# temperature_high    float64
# temperature_low      object
# rained                int64
# snowed                 bool
# overcast             object
# comments             object
# dtype: object

# %%
df_w['temperature_high']=df_w['temperature_high'].astype('int8')
df_w['rained']=df_w['rained'].astype('bool')
df_w=df_w.astype({
    'overcast':'category',
    'comments':'string'
})
df_w.dtypes
# unknow str in a num col
df_w['temperature_low']=pd.to_numeric(df_w['temperature_low'], errors='coerce')
df_w.dtypes
# datetimes
# df_w['date']=df_w['date'].astype('datetime')
df_w['date']=pd.to_datetime(df_w['date'])
df_w.dtypes

# Fixing on reading
df_powers=pd.read_csv('superhero_powers.csv', dtype={
    'hero_names':'string'
})
df_powers.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 168 columns):
#  #    Column                        Dtype
# ---   ------                        -----
#  0    hero_names                    string
#  1    Agility                       bool
#  2    Accelerated Healing           bool
#  3    Lantern Power Ring            bool
#  4    Dimensional Awareness         bool
#  5    Cold Resistance               bool
#  6    Durability                    bool
#  7    Stealth                       bool
#  8    Energy Absorption             bool
#  9    Flight                        bool
#  10   Danger Sense                  bool
#  11   Underwater breathing          bool
#  12   Marksmanship                  bool
#  13   Weapons Master                bool
#  14   Power Augmentation            bool
#  15   Animal Attributes             bool
#  16   Longevity                     bool
#  17   Intelligence                  bool
#  18   Super Strength                bool
#  19   Cryokinesis                   bool
#  20   Telepathy                     bool
#  21   Energy Armor                  bool
#  22   Energy Blasts                 bool
#  23   Duplication                   bool
#  24   Size Changing                 bool
#  25   Density Control               bool
#  26   Stamina                       bool
#  27   Astral Travel                 bool
#  28   Audio Control                 bool
#  29   Dexterity                     bool
#  30   Omnitrix                      bool
#  31   Super Speed                   bool
#  32   Possession                    bool
#  33   Animal Oriented Powers        bool
#  34   Weapon-based Powers           bool
#  35   Electrokinesis                bool
#  36   Darkforce Manipulation        bool
#  37   Death Touch                   bool
#  38   Teleportation                 bool
#  39   Enhanced Senses               bool
#  40   Telekinesis                   bool
#  41   Energy Beams                  bool
#  42   Magic                         bool
#  43   Hyperkinesis                  bool
#  44   Jump                          bool
#  45   Clairvoyance                  bool
#  46   Dimensional Travel            bool
#  47   Power Sense                   bool
#  48   Shapeshifting                 bool
#  49   Peak Human Condition          bool
#  50   Immortality                   bool
#  51   Camouflage                    bool
#  52   Element Control               bool
#  53   Phasing                       bool
#  54   Astral Projection             bool
#  55   Electrical Transport          bool
#  56   Fire Control                  bool
#  57   Projection                    bool
#  58   Summoning                     bool
#  59   Enhanced Memory               bool
#  60   Reflexes                      bool
#  61   Invulnerability               bool
#  62   Energy Constructs             bool
#  63   Force Fields                  bool
#  64   Self-Sustenance               bool
#  65   Anti-Gravity                  bool
#  66   Empathy                       bool
#  67   Power Nullifier               bool
#  68   Radiation Control             bool
#  69   Psionic Powers                bool
#  70   Elasticity                    bool
#  71   Substance Secretion           bool
#  72   Elemental Transmogrification  bool
#  73   Technopath/Cyberpath          bool
#  74   Photographic Reflexes         bool
#  75   Seismic Power                 bool
#  76   Animation                     bool
#  77   Precognition                  bool
#  78   Mind Control                  bool
#  79   Fire Resistance               bool
#  80   Power Absorption              bool
#  81   Enhanced Hearing              bool
#  82   Nova Force                    bool
#  83   Insanity                      bool
#  84   Hypnokinesis                  bool
#  85   Animal Control                bool
#  86   Natural Armor                 bool
#  87   Intangibility                 bool
#  88   Enhanced Sight                bool
#  89   Molecular Manipulation        bool
#  90   Heat Generation               bool
#  91   Adaptation                    bool
#  92   Gliding                       bool
#  93   Power Suit                    bool
#  94   Mind Blast                    bool
#  95   Probability Manipulation      bool
#  96   Gravity Control               bool
#  97   Regeneration                  bool
#  98   Light Control                 bool
#  99   Echolocation                  bool
#  100  Levitation                    bool
#  101  Toxin and Disease Control     bool
#  102  Banish                        bool
#  103  Energy Manipulation           bool
#  104  Heat Resistance               bool
#  105  Natural Weapons               bool
#  106  Time Travel                   bool
#  107  Enhanced Smell                bool
#  108  Illusions                     bool
#  109  Thirstokinesis                bool
#  110  Hair Manipulation             bool
#  111  Illumination                  bool
#  112  Omnipotent                    bool
#  113  Cloaking                      bool
#  114  Changing Armor                bool
#  115  Power Cosmic                  bool
#  116  Biokinesis                    bool
#  117  Water Control                 bool
#  118  Radiation Immunity            bool
#  119  Vision - Telescopic           bool
#  120  Toxin and Disease Resistance  bool
#  121  Spatial Awareness             bool
#  122  Energy Resistance             bool
#  123  Telepathy Resistance          bool
#  124  Molecular Combustion          bool
#  125  Omnilingualism                bool
#  126  Portal Creation               bool
#  127  Magnetism                     bool
#  128  Mind Control Resistance       bool
#  129  Plant Control                 bool
#  130  Sonar                         bool
#  131  Sonic Scream                  bool
#  132  Time Manipulation             bool
#  133  Enhanced Touch                bool
#  134  Magic Resistance              bool
#  135  Invisibility                  bool
#  136  Sub-Mariner                   bool
#  137  Radiation Absorption          bool
#  138  Intuitive aptitude            bool
#  139  Vision - Microscopic          bool
#  140  Melting                       bool
#  141  Wind Control                  bool
#  142  Super Breath                  bool
#  143  Wallcrawling                  bool
#  144  Vision - Night                bool
#  145  Vision - Infrared             bool
#  146  Grim Reaping                  bool
#  147  Matter Absorption             bool
#  148  The Force                     bool
#  149  Resurrection                  bool
#  150  Terrakinesis                  bool
#  151  Vision - Heat                 bool
#  152  Vitakinesis                   bool
#  153  Radar Sense                   bool
#  154  Qwardian Power Ring           bool
#  155  Weather Control               bool
#  156  Vision - X-Ray                bool
#  157  Vision - Thermal              bool
#  158  Web Creation                  bool
#  159  Reality Warping               bool
#  160  Odin Force                    bool
#  161  Symbiote Costume              bool
#  162  Speed Force                   bool
#  163  Phoenix Force                 bool
#  164  Molecular Dissipation         bool
#  165  Vision - Cryo                 bool
#  166  Omnipresent                   bool
#  167  Omniscient                    bool
# dtypes: bool(167), string(1)
# memory usage: 114.1 KB

# %%
df_powers.to_pickle("hpower.pkl")
df_powers_pkl=pd.read_pickle("hpower.pkl")
# Keeps data types - pickle is python specific format
df_powers_pkl.dtypes
# Out:
# hero_names               string
# Agility                    bool
# Accelerated Healing        bool
# Lantern Power Ring         bool
# Dimensional Awareness      bool
#                           ...
# Phoenix Force              bool
# Molecular Dissipation      bool
# Vision - Cryo              bool
# Omnipresent                bool
# Omniscient                 bool
# Length: 168, dtype: object

# %%
left = pd.DataFrame({"col1":[1,2,3,4,5], "col2":['a','b','c','d','e']} )
right=pd.DataFrame({"col1":[3,4,5,6,7], "col2":['f','g','h','i','j']})

# %%
print(right)
# Out:
#    col1 col2
# 0     3    f
# 1     4    g
# 2     5    h
# 3     6    i
# 4     7    j

# %%
print(left)
# Out:
#    col1 col2
# 0     1    a
# 1     2    b
# 2     3    c
# 3     4    d
# 4     5    e

# %%
pd.merge(left,right, on="col1", how="inner")
# Out:
#    col1 col2_x col2_y
# 0     3      c      f
# 1     4      d      g
# 2     5      e      h

# %%
pd.merge(left,right, on="col1", how="outer")
# Out:
#    col1 col2_x col2_y
# 0     1      a    NaN
# 1     2      b    NaN
# 2     3      c      f
# 3     4      d      g
# 4     5      e      h
# 5     6    NaN      i
# 6     7    NaN      j

# %%
pd.merge(left,right, on="col1", how="left")
# Out:
#    col1 col2_x col2_y
# 0     1      a    NaN
# 1     2      b    NaN
# 2     3      c      f
# 3     4      d      g
# 4     5      e      h

# %%
pd.merge(left,right, on="col1", how="right")
# Out:
#    col1 col2_x col2_y
# 0     3      c      f
# 1     4      d      g
# 2     5      e      h
# 3     6    NaN      i
# 4     7    NaN      j

# %%
df1 = pd.DataFrame({'account_id': [1, 2, 3, 11382], 
                    'gender': ['female', 'male', 'female', 'male'], 
                    'age': [55, 25, 29, 39]})


df2 = pd.DataFrame({'account_id': [4, 5, 6, 7], 
                    'gender': ['female', 'male', 'female', 'male'], 
                    'age': [19, 28, 14, 15]})

pd.concat([df1, df2], ignore_index=True)
# Out:
#    account_id  gender  age
# 0           1  female   55
# 1           2    male   25
# 2           3  female   29
# 3       11382    male   39
# 4           4  female   19
# 5           5    male   28
# 6           6  female   14
# 7           7    male   15

# %%
df_powers
# df_marvel
hero=pd.merge(df_marvel, df_powers, left_on='name', right_on='hero_names', how="inner")
hero.head()
# Out:
#             name Gender Eye color               Race Hair color  Height  \
# 0         A-Bomb   Male    yellow              Human    No Hair     203
# 1    Abomination   Male     green  Human / Radiation    No Hair     203
# 2        Abraxas   Male      blue      Cosmic Entity      Black     -99
# 3  Absorbing Man   Male      blue              Human    No Hair     193
# 4      Agent Bob   Male     brown              Human      Brown     178
#
#        Publisher Alignment  Weight     hero_names  ...  Web Creation  \
# 0  Marvel Comics      good     441         A-Bomb  ...         False
# 1  Marvel Comics       bad     441    Abomination  ...         False
# 2  Marvel Comics       bad     -99        Abraxas  ...         False
# 3  Marvel Comics       bad     122  Absorbing Man  ...         False
# 4  Marvel Comics      good      81      Agent Bob  ...         False
#
#    Reality Warping  Odin Force  Symbiote Costume  Speed Force  Phoenix Force  \
# 0            False       False             False        False          False
# 1            False       False             False        False          False
# 2            False       False             False        False          False
# 3            False       False             False        False          False
# 4            False       False             False        False          False
#
#    Molecular Dissipation  Vision - Cryo  Omnipresent  Omniscient
# 0                  False          False        False       False
# 1                  False          False        False       False
# 2                  False          False        False       False
# 3                  False          False        False       False
# 4                  False          False        False       False
#
# [5 rows x 177 columns]

# %%
hero.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 341 entries, 0 to 340
# Data columns (total 177 columns):
#  #    Column                        Dtype
# ---   ------                        -----
#  0    name                          object
#  1    Gender                        object
#  2    Eye color                     object
#  3    Race                          object
#  4    Hair color                    object
#  5    Height                        int64
#  6    Publisher                     object
#  7    Alignment                     object
#  8    Weight                        int64
#  9    hero_names                    string
#  10   Agility                       bool
#  11   Accelerated Healing           bool
#  12   Lantern Power Ring            bool
#  13   Dimensional Awareness         bool
#  14   Cold Resistance               bool
#  15   Durability                    bool
#  16   Stealth                       bool
#  17   Energy Absorption             bool
#  18   Flight                        bool
#  19   Danger Sense                  bool
#  20   Underwater breathing          bool
#  21   Marksmanship                  bool
#  22   Weapons Master                bool
#  23   Power Augmentation            bool
#  24   Animal Attributes             bool
#  25   Longevity                     bool
#  26   Intelligence                  bool
#  27   Super Strength                bool
#  28   Cryokinesis                   bool
#  29   Telepathy                     bool
#  30   Energy Armor                  bool
#  31   Energy Blasts                 bool
#  32   Duplication                   bool
#  33   Size Changing                 bool
#  34   Density Control               bool
#  35   Stamina                       bool
#  36   Astral Travel                 bool
#  37   Audio Control                 bool
#  38   Dexterity                     bool
#  39   Omnitrix                      bool
#  40   Super Speed                   bool
#  41   Possession                    bool
#  42   Animal Oriented Powers        bool
#  43   Weapon-based Powers           bool
#  44   Electrokinesis                bool
#  45   Darkforce Manipulation        bool
#  46   Death Touch                   bool
#  47   Teleportation                 bool
#  48   Enhanced Senses               bool
#  49   Telekinesis                   bool
#  50   Energy Beams                  bool
#  51   Magic                         bool
#  52   Hyperkinesis                  bool
#  53   Jump                          bool
#  54   Clairvoyance                  bool
#  55   Dimensional Travel            bool
#  56   Power Sense                   bool
#  57   Shapeshifting                 bool
#  58   Peak Human Condition          bool
#  59   Immortality                   bool
#  60   Camouflage                    bool
#  61   Element Control               bool
#  62   Phasing                       bool
#  63   Astral Projection             bool
#  64   Electrical Transport          bool
#  65   Fire Control                  bool
#  66   Projection                    bool
#  67   Summoning                     bool
#  68   Enhanced Memory               bool
#  69   Reflexes                      bool
#  70   Invulnerability               bool
#  71   Energy Constructs             bool
#  72   Force Fields                  bool
#  73   Self-Sustenance               bool
#  74   Anti-Gravity                  bool
#  75   Empathy                       bool
#  76   Power Nullifier               bool
#  77   Radiation Control             bool
#  78   Psionic Powers                bool
#  79   Elasticity                    bool
#  80   Substance Secretion           bool
#  81   Elemental Transmogrification  bool
#  82   Technopath/Cyberpath          bool
#  83   Photographic Reflexes         bool
#  84   Seismic Power                 bool
#  85   Animation                     bool
#  86   Precognition                  bool
#  87   Mind Control                  bool
#  88   Fire Resistance               bool
#  89   Power Absorption              bool
#  90   Enhanced Hearing              bool
#  91   Nova Force                    bool
#  92   Insanity                      bool
#  93   Hypnokinesis                  bool
#  94   Animal Control                bool
#  95   Natural Armor                 bool
#  96   Intangibility                 bool
#  97   Enhanced Sight                bool
#  98   Molecular Manipulation        bool
#  99   Heat Generation               bool
#  100  Adaptation                    bool
#  101  Gliding                       bool
#  102  Power Suit                    bool
#  103  Mind Blast                    bool
#  104  Probability Manipulation      bool
#  105  Gravity Control               bool
#  106  Regeneration                  bool
#  107  Light Control                 bool
#  108  Echolocation                  bool
#  109  Levitation                    bool
#  110  Toxin and Disease Control     bool
#  111  Banish                        bool
#  112  Energy Manipulation           bool
#  113  Heat Resistance               bool
#  114  Natural Weapons               bool
#  115  Time Travel                   bool
#  116  Enhanced Smell                bool
#  117  Illusions                     bool
#  118  Thirstokinesis                bool
#  119  Hair Manipulation             bool
#  120  Illumination                  bool
#  121  Omnipotent                    bool
#  122  Cloaking                      bool
#  123  Changing Armor                bool
#  124  Power Cosmic                  bool
#  125  Biokinesis                    bool
#  126  Water Control                 bool
#  127  Radiation Immunity            bool
#  128  Vision - Telescopic           bool
#  129  Toxin and Disease Resistance  bool
#  130  Spatial Awareness             bool
#  131  Energy Resistance             bool
#  132  Telepathy Resistance          bool
#  133  Molecular Combustion          bool
#  134  Omnilingualism                bool
#  135  Portal Creation               bool
#  136  Magnetism                     bool
#  137  Mind Control Resistance       bool
#  138  Plant Control                 bool
#  139  Sonar                         bool
#  140  Sonic Scream                  bool
#  141  Time Manipulation             bool
#  142  Enhanced Touch                bool
#  143  Magic Resistance              bool
#  144  Invisibility                  bool
#  145  Sub-Mariner                   bool
#  146  Radiation Absorption          bool
#  147  Intuitive aptitude            bool
#  148  Vision - Microscopic          bool
#  149  Melting                       bool
#  150  Wind Control                  bool
#  151  Super Breath                  bool
#  152  Wallcrawling                  bool
#  153  Vision - Night                bool
#  154  Vision - Infrared             bool
#  155  Grim Reaping                  bool
#  156  Matter Absorption             bool
#  157  The Force                     bool
#  158  Resurrection                  bool
#  159  Terrakinesis                  bool
#  160  Vision - Heat                 bool
#  161  Vitakinesis                   bool
#  162  Radar Sense                   bool
#  163  Qwardian Power Ring           bool
#  164  Weather Control               bool
#  165  Vision - X-Ray                bool
#  166  Vision - Thermal              bool
#  167  Web Creation                  bool
#  168  Reality Warping               bool
#  169  Odin Force                    bool
#  170  Symbiote Costume              bool
#  171  Speed Force                   bool
#  172  Phoenix Force                 bool
#  173  Molecular Dissipation         bool
#  174  Vision - Cryo                 bool
#  175  Omnipresent                   bool
#  176  Omniscient                    bool
# dtypes: bool(167), int64(2), object(7), string(1)
# memory usage: 84.9+ KB

# %%
hero.columns=hero.columns.str.lower()

# %%
hero.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 341 entries, 0 to 340
# Data columns (total 177 columns):
#  #    Column                        Dtype
# ---   ------                        -----
#  0    name                          object
#  1    gender                        object
#  2    eye color                     object
#  3    race                          object
#  4    hair color                    object
#  5    height                        int64
#  6    publisher                     object
#  7    alignment                     object
#  8    weight                        int64
#  9    hero_names                    string
#  10   agility                       bool
#  11   accelerated healing           bool
#  12   lantern power ring            bool
#  13   dimensional awareness         bool
#  14   cold resistance               bool
#  15   durability                    bool
#  16   stealth                       bool
#  17   energy absorption             bool
#  18   flight                        bool
#  19   danger sense                  bool
#  20   underwater breathing          bool
#  21   marksmanship                  bool
#  22   weapons master                bool
#  23   power augmentation            bool
#  24   animal attributes             bool
#  25   longevity                     bool
#  26   intelligence                  bool
#  27   super strength                bool
#  28   cryokinesis                   bool
#  29   telepathy                     bool
#  30   energy armor                  bool
#  31   energy blasts                 bool
#  32   duplication                   bool
#  33   size changing                 bool
#  34   density control               bool
#  35   stamina                       bool
#  36   astral travel                 bool
#  37   audio control                 bool
#  38   dexterity                     bool
#  39   omnitrix                      bool
#  40   super speed                   bool
#  41   possession                    bool
#  42   animal oriented powers        bool
#  43   weapon-based powers           bool
#  44   electrokinesis                bool
#  45   darkforce manipulation        bool
#  46   death touch                   bool
#  47   teleportation                 bool
#  48   enhanced senses               bool
#  49   telekinesis                   bool
#  50   energy beams                  bool
#  51   magic                         bool
#  52   hyperkinesis                  bool
#  53   jump                          bool
#  54   clairvoyance                  bool
#  55   dimensional travel            bool
#  56   power sense                   bool
#  57   shapeshifting                 bool
#  58   peak human condition          bool
#  59   immortality                   bool
#  60   camouflage                    bool
#  61   element control               bool
#  62   phasing                       bool
#  63   astral projection             bool
#  64   electrical transport          bool
#  65   fire control                  bool
#  66   projection                    bool
#  67   summoning                     bool
#  68   enhanced memory               bool
#  69   reflexes                      bool
#  70   invulnerability               bool
#  71   energy constructs             bool
#  72   force fields                  bool
#  73   self-sustenance               bool
#  74   anti-gravity                  bool
#  75   empathy                       bool
#  76   power nullifier               bool
#  77   radiation control             bool
#  78   psionic powers                bool
#  79   elasticity                    bool
#  80   substance secretion           bool
#  81   elemental transmogrification  bool
#  82   technopath/cyberpath          bool
#  83   photographic reflexes         bool
#  84   seismic power                 bool
#  85   animation                     bool
#  86   precognition                  bool
#  87   mind control                  bool
#  88   fire resistance               bool
#  89   power absorption              bool
#  90   enhanced hearing              bool
#  91   nova force                    bool
#  92   insanity                      bool
#  93   hypnokinesis                  bool
#  94   animal control                bool
#  95   natural armor                 bool
#  96   intangibility                 bool
#  97   enhanced sight                bool
#  98   molecular manipulation        bool
#  99   heat generation               bool
#  100  adaptation                    bool
#  101  gliding                       bool
#  102  power suit                    bool
#  103  mind blast                    bool
#  104  probability manipulation      bool
#  105  gravity control               bool
#  106  regeneration                  bool
#  107  light control                 bool
#  108  echolocation                  bool
#  109  levitation                    bool
#  110  toxin and disease control     bool
#  111  banish                        bool
#  112  energy manipulation           bool
#  113  heat resistance               bool
#  114  natural weapons               bool
#  115  time travel                   bool
#  116  enhanced smell                bool
#  117  illusions                     bool
#  118  thirstokinesis                bool
#  119  hair manipulation             bool
#  120  illumination                  bool
#  121  omnipotent                    bool
#  122  cloaking                      bool
#  123  changing armor                bool
#  124  power cosmic                  bool
#  125  biokinesis                    bool
#  126  water control                 bool
#  127  radiation immunity            bool
#  128  vision - telescopic           bool
#  129  toxin and disease resistance  bool
#  130  spatial awareness             bool
#  131  energy resistance             bool
#  132  telepathy resistance          bool
#  133  molecular combustion          bool
#  134  omnilingualism                bool
#  135  portal creation               bool
#  136  magnetism                     bool
#  137  mind control resistance       bool
#  138  plant control                 bool
#  139  sonar                         bool
#  140  sonic scream                  bool
#  141  time manipulation             bool
#  142  enhanced touch                bool
#  143  magic resistance              bool
#  144  invisibility                  bool
#  145  sub-mariner                   bool
#  146  radiation absorption          bool
#  147  intuitive aptitude            bool
#  148  vision - microscopic          bool
#  149  melting                       bool
#  150  wind control                  bool
#  151  super breath                  bool
#  152  wallcrawling                  bool
#  153  vision - night                bool
#  154  vision - infrared             bool
#  155  grim reaping                  bool
#  156  matter absorption             bool
#  157  the force                     bool
#  158  resurrection                  bool
#  159  terrakinesis                  bool
#  160  vision - heat                 bool
#  161  vitakinesis                   bool
#  162  radar sense                   bool
#  163  qwardian power ring           bool
#  164  weather control               bool
#  165  vision - x-ray                bool
#  166  vision - thermal              bool
#  167  web creation                  bool
#  168  reality warping               bool
#  169  odin force                    bool
#  170  symbiote costume              bool
#  171  speed force                   bool
#  172  phoenix force                 bool
#  173  molecular dissipation         bool
#  174  vision - cryo                 bool
#  175  omnipresent                   bool
#  176  omniscient                    bool
# dtypes: bool(167), int64(2), object(7), string(1)
# memory usage: 84.9+ KB

# %%
# Reassing since rename returns a new copy
hero=hero.rename(columns={'hero_names':'hero names'})
hero.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 341 entries, 0 to 340
# Data columns (total 177 columns):
#  #    Column                        Dtype
# ---   ------                        -----
#  0    name                          object
#  1    gender                        object
#  2    eye color                     object
#  3    race                          object
#  4    hair color                    object
#  5    height                        int64
#  6    publisher                     object
#  7    alignment                     object
#  8    weight                        int64
#  9    hero names                    string
#  10   agility                       bool
#  11   accelerated healing           bool
#  12   lantern power ring            bool
#  13   dimensional awareness         bool
#  14   cold resistance               bool
#  15   durability                    bool
#  16   stealth                       bool
#  17   energy absorption             bool
#  18   flight                        bool
#  19   danger sense                  bool
#  20   underwater breathing          bool
#  21   marksmanship                  bool
#  22   weapons master                bool
#  23   power augmentation            bool
#  24   animal attributes             bool
#  25   longevity                     bool
#  26   intelligence                  bool
#  27   super strength                bool
#  28   cryokinesis                   bool
#  29   telepathy                     bool
#  30   energy armor                  bool
#  31   energy blasts                 bool
#  32   duplication                   bool
#  33   size changing                 bool
#  34   density control               bool
#  35   stamina                       bool
#  36   astral travel                 bool
#  37   audio control                 bool
#  38   dexterity                     bool
#  39   omnitrix                      bool
#  40   super speed                   bool
#  41   possession                    bool
#  42   animal oriented powers        bool
#  43   weapon-based powers           bool
#  44   electrokinesis                bool
#  45   darkforce manipulation        bool
#  46   death touch                   bool
#  47   teleportation                 bool
#  48   enhanced senses               bool
#  49   telekinesis                   bool
#  50   energy beams                  bool
#  51   magic                         bool
#  52   hyperkinesis                  bool
#  53   jump                          bool
#  54   clairvoyance                  bool
#  55   dimensional travel            bool
#  56   power sense                   bool
#  57   shapeshifting                 bool
#  58   peak human condition          bool
#  59   immortality                   bool
#  60   camouflage                    bool
#  61   element control               bool
#  62   phasing                       bool
#  63   astral projection             bool
#  64   electrical transport          bool
#  65   fire control                  bool
#  66   projection                    bool
#  67   summoning                     bool
#  68   enhanced memory               bool
#  69   reflexes                      bool
#  70   invulnerability               bool
#  71   energy constructs             bool
#  72   force fields                  bool
#  73   self-sustenance               bool
#  74   anti-gravity                  bool
#  75   empathy                       bool
#  76   power nullifier               bool
#  77   radiation control             bool
#  78   psionic powers                bool
#  79   elasticity                    bool
#  80   substance secretion           bool
#  81   elemental transmogrification  bool
#  82   technopath/cyberpath          bool
#  83   photographic reflexes         bool
#  84   seismic power                 bool
#  85   animation                     bool
#  86   precognition                  bool
#  87   mind control                  bool
#  88   fire resistance               bool
#  89   power absorption              bool
#  90   enhanced hearing              bool
#  91   nova force                    bool
#  92   insanity                      bool
#  93   hypnokinesis                  bool
#  94   animal control                bool
#  95   natural armor                 bool
#  96   intangibility                 bool
#  97   enhanced sight                bool
#  98   molecular manipulation        bool
#  99   heat generation               bool
#  100  adaptation                    bool
#  101  gliding                       bool
#  102  power suit                    bool
#  103  mind blast                    bool
#  104  probability manipulation      bool
#  105  gravity control               bool
#  106  regeneration                  bool
#  107  light control                 bool
#  108  echolocation                  bool
#  109  levitation                    bool
#  110  toxin and disease control     bool
#  111  banish                        bool
#  112  energy manipulation           bool
#  113  heat resistance               bool
#  114  natural weapons               bool
#  115  time travel                   bool
#  116  enhanced smell                bool
#  117  illusions                     bool
#  118  thirstokinesis                bool
#  119  hair manipulation             bool
#  120  illumination                  bool
#  121  omnipotent                    bool
#  122  cloaking                      bool
#  123  changing armor                bool
#  124  power cosmic                  bool
#  125  biokinesis                    bool
#  126  water control                 bool
#  127  radiation immunity            bool
#  128  vision - telescopic           bool
#  129  toxin and disease resistance  bool
#  130  spatial awareness             bool
#  131  energy resistance             bool
#  132  telepathy resistance          bool
#  133  molecular combustion          bool
#  134  omnilingualism                bool
#  135  portal creation               bool
#  136  magnetism                     bool
#  137  mind control resistance       bool
#  138  plant control                 bool
#  139  sonar                         bool
#  140  sonic scream                  bool
#  141  time manipulation             bool
#  142  enhanced touch                bool
#  143  magic resistance              bool
#  144  invisibility                  bool
#  145  sub-mariner                   bool
#  146  radiation absorption          bool
#  147  intuitive aptitude            bool
#  148  vision - microscopic          bool
#  149  melting                       bool
#  150  wind control                  bool
#  151  super breath                  bool
#  152  wallcrawling                  bool
#  153  vision - night                bool
#  154  vision - infrared             bool
#  155  grim reaping                  bool
#  156  matter absorption             bool
#  157  the force                     bool
#  158  resurrection                  bool
#  159  terrakinesis                  bool
#  160  vision - heat                 bool
#  161  vitakinesis                   bool
#  162  radar sense                   bool
#  163  qwardian power ring           bool
#  164  weather control               bool
#  165  vision - x-ray                bool
#  166  vision - thermal              bool
#  167  web creation                  bool
#  168  reality warping               bool
#  169  odin force                    bool
#  170  symbiote costume              bool
#  171  speed force                   bool
#  172  phoenix force                 bool
#  173  molecular dissipation         bool
#  174  vision - cryo                 bool
#  175  omnipresent                   bool
#  176  omniscient                    bool
# dtypes: bool(167), int64(2), object(7), string(1)
# memory usage: 84.9+ KB

# %%
hero=hero.rename(columns=str.upper)
hero.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 341 entries, 0 to 340
# Data columns (total 177 columns):
#  #    Column                        Dtype
# ---   ------                        -----
#  0    NAME                          object
#  1    GENDER                        object
#  2    EYE COLOR                     object
#  3    RACE                          object
#  4    HAIR COLOR                    object
#  5    HEIGHT                        int64
#  6    PUBLISHER                     object
#  7    ALIGNMENT                     object
#  8    WEIGHT                        int64
#  9    HERO NAMES                    string
#  10   AGILITY                       bool
#  11   ACCELERATED HEALING           bool
#  12   LANTERN POWER RING            bool
#  13   DIMENSIONAL AWARENESS         bool
#  14   COLD RESISTANCE               bool
#  15   DURABILITY                    bool
#  16   STEALTH                       bool
#  17   ENERGY ABSORPTION             bool
#  18   FLIGHT                        bool
#  19   DANGER SENSE                  bool
#  20   UNDERWATER BREATHING          bool
#  21   MARKSMANSHIP                  bool
#  22   WEAPONS MASTER                bool
#  23   POWER AUGMENTATION            bool
#  24   ANIMAL ATTRIBUTES             bool
#  25   LONGEVITY                     bool
#  26   INTELLIGENCE                  bool
#  27   SUPER STRENGTH                bool
#  28   CRYOKINESIS                   bool
#  29   TELEPATHY                     bool
#  30   ENERGY ARMOR                  bool
#  31   ENERGY BLASTS                 bool
#  32   DUPLICATION                   bool
#  33   SIZE CHANGING                 bool
#  34   DENSITY CONTROL               bool
#  35   STAMINA                       bool
#  36   ASTRAL TRAVEL                 bool
#  37   AUDIO CONTROL                 bool
#  38   DEXTERITY                     bool
#  39   OMNITRIX                      bool
#  40   SUPER SPEED                   bool
#  41   POSSESSION                    bool
#  42   ANIMAL ORIENTED POWERS        bool
#  43   WEAPON-BASED POWERS           bool
#  44   ELECTROKINESIS                bool
#  45   DARKFORCE MANIPULATION        bool
#  46   DEATH TOUCH                   bool
#  47   TELEPORTATION                 bool
#  48   ENHANCED SENSES               bool
#  49   TELEKINESIS                   bool
#  50   ENERGY BEAMS                  bool
#  51   MAGIC                         bool
#  52   HYPERKINESIS                  bool
#  53   JUMP                          bool
#  54   CLAIRVOYANCE                  bool
#  55   DIMENSIONAL TRAVEL            bool
#  56   POWER SENSE                   bool
#  57   SHAPESHIFTING                 bool
#  58   PEAK HUMAN CONDITION          bool
#  59   IMMORTALITY                   bool
#  60   CAMOUFLAGE                    bool
#  61   ELEMENT CONTROL               bool
#  62   PHASING                       bool
#  63   ASTRAL PROJECTION             bool
#  64   ELECTRICAL TRANSPORT          bool
#  65   FIRE CONTROL                  bool
#  66   PROJECTION                    bool
#  67   SUMMONING                     bool
#  68   ENHANCED MEMORY               bool
#  69   REFLEXES                      bool
#  70   INVULNERABILITY               bool
#  71   ENERGY CONSTRUCTS             bool
#  72   FORCE FIELDS                  bool
#  73   SELF-SUSTENANCE               bool
#  74   ANTI-GRAVITY                  bool
#  75   EMPATHY                       bool
#  76   POWER NULLIFIER               bool
#  77   RADIATION CONTROL             bool
#  78   PSIONIC POWERS                bool
#  79   ELASTICITY                    bool
#  80   SUBSTANCE SECRETION           bool
#  81   ELEMENTAL TRANSMOGRIFICATION  bool
#  82   TECHNOPATH/CYBERPATH          bool
#  83   PHOTOGRAPHIC REFLEXES         bool
#  84   SEISMIC POWER                 bool
#  85   ANIMATION                     bool
#  86   PRECOGNITION                  bool
#  87   MIND CONTROL                  bool
#  88   FIRE RESISTANCE               bool
#  89   POWER ABSORPTION              bool
#  90   ENHANCED HEARING              bool
#  91   NOVA FORCE                    bool
#  92   INSANITY                      bool
#  93   HYPNOKINESIS                  bool
#  94   ANIMAL CONTROL                bool
#  95   NATURAL ARMOR                 bool
#  96   INTANGIBILITY                 bool
#  97   ENHANCED SIGHT                bool
#  98   MOLECULAR MANIPULATION        bool
#  99   HEAT GENERATION               bool
#  100  ADAPTATION                    bool
#  101  GLIDING                       bool
#  102  POWER SUIT                    bool
#  103  MIND BLAST                    bool
#  104  PROBABILITY MANIPULATION      bool
#  105  GRAVITY CONTROL               bool
#  106  REGENERATION                  bool
#  107  LIGHT CONTROL                 bool
#  108  ECHOLOCATION                  bool
#  109  LEVITATION                    bool
#  110  TOXIN AND DISEASE CONTROL     bool
#  111  BANISH                        bool
#  112  ENERGY MANIPULATION           bool
#  113  HEAT RESISTANCE               bool
#  114  NATURAL WEAPONS               bool
#  115  TIME TRAVEL                   bool
#  116  ENHANCED SMELL                bool
#  117  ILLUSIONS                     bool
#  118  THIRSTOKINESIS                bool
#  119  HAIR MANIPULATION             bool
#  120  ILLUMINATION                  bool
#  121  OMNIPOTENT                    bool
#  122  CLOAKING                      bool
#  123  CHANGING ARMOR                bool
#  124  POWER COSMIC                  bool
#  125  BIOKINESIS                    bool
#  126  WATER CONTROL                 bool
#  127  RADIATION IMMUNITY            bool
#  128  VISION - TELESCOPIC           bool
#  129  TOXIN AND DISEASE RESISTANCE  bool
#  130  SPATIAL AWARENESS             bool
#  131  ENERGY RESISTANCE             bool
#  132  TELEPATHY RESISTANCE          bool
#  133  MOLECULAR COMBUSTION          bool
#  134  OMNILINGUALISM                bool
#  135  PORTAL CREATION               bool
#  136  MAGNETISM                     bool
#  137  MIND CONTROL RESISTANCE       bool
#  138  PLANT CONTROL                 bool
#  139  SONAR                         bool
#  140  SONIC SCREAM                  bool
#  141  TIME MANIPULATION             bool
#  142  ENHANCED TOUCH                bool
#  143  MAGIC RESISTANCE              bool
#  144  INVISIBILITY                  bool
#  145  SUB-MARINER                   bool
#  146  RADIATION ABSORPTION          bool
#  147  INTUITIVE APTITUDE            bool
#  148  VISION - MICROSCOPIC          bool
#  149  MELTING                       bool
#  150  WIND CONTROL                  bool
#  151  SUPER BREATH                  bool
#  152  WALLCRAWLING                  bool
#  153  VISION - NIGHT                bool
#  154  VISION - INFRARED             bool
#  155  GRIM REAPING                  bool
#  156  MATTER ABSORPTION             bool
#  157  THE FORCE                     bool
#  158  RESURRECTION                  bool
#  159  TERRAKINESIS                  bool
#  160  VISION - HEAT                 bool
#  161  VITAKINESIS                   bool
#  162  RADAR SENSE                   bool
#  163  QWARDIAN POWER RING           bool
#  164  WEATHER CONTROL               bool
#  165  VISION - X-RAY                bool
#  166  VISION - THERMAL              bool
#  167  WEB CREATION                  bool
#  168  REALITY WARPING               bool
#  169  ODIN FORCE                    bool
#  170  SYMBIOTE COSTUME              bool
#  171  SPEED FORCE                   bool
#  172  PHOENIX FORCE                 bool
#  173  MOLECULAR DISSIPATION         bool
#  174  VISION - CRYO                 bool
#  175  OMNIPRESENT                   bool
#  176  OMNISCIENT                    bool
# dtypes: bool(167), int64(2), object(7), string(1)
# memory usage: 84.9+ KB

# %%
hero=hero.rename(mapper=str.lower, axis=1)
hero.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 341 entries, 0 to 340
# Data columns (total 177 columns):
#  #    Column                        Dtype
# ---   ------                        -----
#  0    name                          object
#  1    gender                        object
#  2    eye color                     object
#  3    race                          object
#  4    hair color                    object
#  5    height                        int64
#  6    publisher                     object
#  7    alignment                     object
#  8    weight                        int64
#  9    hero names                    string
#  10   agility                       bool
#  11   accelerated healing           bool
#  12   lantern power ring            bool
#  13   dimensional awareness         bool
#  14   cold resistance               bool
#  15   durability                    bool
#  16   stealth                       bool
#  17   energy absorption             bool
#  18   flight                        bool
#  19   danger sense                  bool
#  20   underwater breathing          bool
#  21   marksmanship                  bool
#  22   weapons master                bool
#  23   power augmentation            bool
#  24   animal attributes             bool
#  25   longevity                     bool
#  26   intelligence                  bool
#  27   super strength                bool
#  28   cryokinesis                   bool
#  29   telepathy                     bool
#  30   energy armor                  bool
#  31   energy blasts                 bool
#  32   duplication                   bool
#  33   size changing                 bool
#  34   density control               bool
#  35   stamina                       bool
#  36   astral travel                 bool
#  37   audio control                 bool
#  38   dexterity                     bool
#  39   omnitrix                      bool
#  40   super speed                   bool
#  41   possession                    bool
#  42   animal oriented powers        bool
#  43   weapon-based powers           bool
#  44   electrokinesis                bool
#  45   darkforce manipulation        bool
#  46   death touch                   bool
#  47   teleportation                 bool
#  48   enhanced senses               bool
#  49   telekinesis                   bool
#  50   energy beams                  bool
#  51   magic                         bool
#  52   hyperkinesis                  bool
#  53   jump                          bool
#  54   clairvoyance                  bool
#  55   dimensional travel            bool
#  56   power sense                   bool
#  57   shapeshifting                 bool
#  58   peak human condition          bool
#  59   immortality                   bool
#  60   camouflage                    bool
#  61   element control               bool
#  62   phasing                       bool
#  63   astral projection             bool
#  64   electrical transport          bool
#  65   fire control                  bool
#  66   projection                    bool
#  67   summoning                     bool
#  68   enhanced memory               bool
#  69   reflexes                      bool
#  70   invulnerability               bool
#  71   energy constructs             bool
#  72   force fields                  bool
#  73   self-sustenance               bool
#  74   anti-gravity                  bool
#  75   empathy                       bool
#  76   power nullifier               bool
#  77   radiation control             bool
#  78   psionic powers                bool
#  79   elasticity                    bool
#  80   substance secretion           bool
#  81   elemental transmogrification  bool
#  82   technopath/cyberpath          bool
#  83   photographic reflexes         bool
#  84   seismic power                 bool
#  85   animation                     bool
#  86   precognition                  bool
#  87   mind control                  bool
#  88   fire resistance               bool
#  89   power absorption              bool
#  90   enhanced hearing              bool
#  91   nova force                    bool
#  92   insanity                      bool
#  93   hypnokinesis                  bool
#  94   animal control                bool
#  95   natural armor                 bool
#  96   intangibility                 bool
#  97   enhanced sight                bool
#  98   molecular manipulation        bool
#  99   heat generation               bool
#  100  adaptation                    bool
#  101  gliding                       bool
#  102  power suit                    bool
#  103  mind blast                    bool
#  104  probability manipulation      bool
#  105  gravity control               bool
#  106  regeneration                  bool
#  107  light control                 bool
#  108  echolocation                  bool
#  109  levitation                    bool
#  110  toxin and disease control     bool
#  111  banish                        bool
#  112  energy manipulation           bool
#  113  heat resistance               bool
#  114  natural weapons               bool
#  115  time travel                   bool
#  116  enhanced smell                bool
#  117  illusions                     bool
#  118  thirstokinesis                bool
#  119  hair manipulation             bool
#  120  illumination                  bool
#  121  omnipotent                    bool
#  122  cloaking                      bool
#  123  changing armor                bool
#  124  power cosmic                  bool
#  125  biokinesis                    bool
#  126  water control                 bool
#  127  radiation immunity            bool
#  128  vision - telescopic           bool
#  129  toxin and disease resistance  bool
#  130  spatial awareness             bool
#  131  energy resistance             bool
#  132  telepathy resistance          bool
#  133  molecular combustion          bool
#  134  omnilingualism                bool
#  135  portal creation               bool
#  136  magnetism                     bool
#  137  mind control resistance       bool
#  138  plant control                 bool
#  139  sonar                         bool
#  140  sonic scream                  bool
#  141  time manipulation             bool
#  142  enhanced touch                bool
#  143  magic resistance              bool
#  144  invisibility                  bool
#  145  sub-mariner                   bool
#  146  radiation absorption          bool
#  147  intuitive aptitude            bool
#  148  vision - microscopic          bool
#  149  melting                       bool
#  150  wind control                  bool
#  151  super breath                  bool
#  152  wallcrawling                  bool
#  153  vision - night                bool
#  154  vision - infrared             bool
#  155  grim reaping                  bool
#  156  matter absorption             bool
#  157  the force                     bool
#  158  resurrection                  bool
#  159  terrakinesis                  bool
#  160  vision - heat                 bool
#  161  vitakinesis                   bool
#  162  radar sense                   bool
#  163  qwardian power ring           bool
#  164  weather control               bool
#  165  vision - x-ray                bool
#  166  vision - thermal              bool
#  167  web creation                  bool
#  168  reality warping               bool
#  169  odin force                    bool
#  170  symbiote costume              bool
#  171  speed force                   bool
#  172  phoenix force                 bool
#  173  molecular dissipation         bool
#  174  vision - cryo                 bool
#  175  omnipresent                   bool
#  176  omniscient                    bool
# dtypes: bool(167), int64(2), object(7), string(1)
# memory usage: 84.9+ KB

# %%
hero["name"]
# Out:
# 0               A-Bomb
# 1          Abomination
# 2              Abraxas
# 3        Absorbing Man
# 4            Agent Bob
#             ...
# 336               X-23
# 337              X-Man
# 338       Yellowjacket
# 339    Yellowjacket II
# 340               Ymir
# Name: name, Length: 341, dtype: object

# %%
hero[['name', 'gender']]
# Out:
#                 name  gender
# 0             A-Bomb    Male
# 1        Abomination    Male
# 2            Abraxas    Male
# 3      Absorbing Man    Male
# 4          Agent Bob    Male
# ..               ...     ...
# 336             X-23  Female
# 337            X-Man    Male
# 338     Yellowjacket    Male
# 339  Yellowjacket II  Female
# 340             Ymir    Male
#
# [341 rows x 2 columns]

# %%
hero.select_dtypes(include="number")
hero.select_dtypes(exclude="number")
hero.select_dtypes(include=["int64","category"])
# Out:
#      height  weight
# 0       203     441
# 1       203     441
# 2       -99     -99
# 3       193     122
# 4       178      81
# ..      ...     ...
# 336     155      50
# 337     175      61
# 338     183      83
# 339     165      52
# 340     305     -99
#
# [341 rows x 2 columns]

# %%
hero.loc[0]
# Out:
# name                      A-Bomb
# gender                      Male
# eye color                 yellow
# race                       Human
# hair color               No Hair
#                           ...
# phoenix force              False
# molecular dissipation      False
# vision - cryo              False
# omnipresent                False
# omniscient                 False
# Name: 0, Length: 177, dtype: object

# %%
hero.loc[[0,1]]
# Out:
#           name gender eye color               race hair color  height  \
# 0       A-Bomb   Male    yellow              Human    No Hair     203
# 1  Abomination   Male     green  Human / Radiation    No Hair     203
#
#        publisher alignment  weight   hero names  ...  web creation  \
# 0  Marvel Comics      good     441       A-Bomb  ...         False
# 1  Marvel Comics       bad     441  Abomination  ...         False
#
#    reality warping  odin force  symbiote costume  speed force  phoenix force  \
# 0            False       False             False        False          False
# 1            False       False             False        False          False
#
#    molecular dissipation  vision - cryo  omnipresent  omniscient
# 0                  False          False        False       False
# 1                  False          False        False       False
#
# [2 rows x 177 columns]

# %%
hero.loc[0:4] # Inclusive both
# Out:
#             name gender eye color               race hair color  height  \
# 0         A-Bomb   Male    yellow              Human    No Hair     203
# 1    Abomination   Male     green  Human / Radiation    No Hair     203
# 2        Abraxas   Male      blue      Cosmic Entity      Black     -99
# 3  Absorbing Man   Male      blue              Human    No Hair     193
# 4      Agent Bob   Male     brown              Human      Brown     178
#
#        publisher alignment  weight     hero names  ...  web creation  \
# 0  Marvel Comics      good     441         A-Bomb  ...         False
# 1  Marvel Comics       bad     441    Abomination  ...         False
# 2  Marvel Comics       bad     -99        Abraxas  ...         False
# 3  Marvel Comics       bad     122  Absorbing Man  ...         False
# 4  Marvel Comics      good      81      Agent Bob  ...         False
#
#    reality warping  odin force  symbiote costume  speed force  phoenix force  \
# 0            False       False             False        False          False
# 1            False       False             False        False          False
# 2            False       False             False        False          False
# 3            False       False             False        False          False
# 4            False       False             False        False          False
#
#    molecular dissipation  vision - cryo  omnipresent  omniscient
# 0                  False          False        False       False
# 1                  False          False        False       False
# 2                  False          False        False       False
# 3                  False          False        False       False
# 4                  False          False        False       False
#
# [5 rows x 177 columns]

# %%
hero_name = hero.set_index('name')
hero_name.index
hero_name.loc['Abomination']
# Out:
# gender                                Male
# eye color                            green
# race                     Human / Radiation
# hair color                         No Hair
# height                                 203
#                                ...
# phoenix force                        False
# molecular dissipation                False
# vision - cryo                        False
# omnipresent                          False
# omniscient                           False
# Name: Abomination, Length: 176, dtype: object

# %%
hero_name.loc[['Weapon XI', 'Winter Soldier']]
# Out:
#                gender eye color   race hair color  height      publisher  \
# name
# Weapon XI        Male         -      -          -     -99  Marvel Comics
# Winter Soldier   Male     brown  Human      Brown     175  Marvel Comics
#
#                alignment  weight      hero names  agility  ...  web creation  \
# name                                                       ...
# Weapon XI            bad     -99       Weapon XI     True  ...         False
# Winter Soldier      good     117  Winter Soldier    False  ...         False
#
#                 reality warping  odin force  symbiote costume  speed force  \
# name
# Weapon XI                 False       False             False        False
# Winter Soldier            False       False             False        False
#
#                 phoenix force  molecular dissipation  vision - cryo  \
# name
# Weapon XI               False                  False          False
# Winter Soldier          False                  False          False
#
#                 omnipresent  omniscient
# name
# Weapon XI             False       False
# Winter Soldier        False       False
#
# [2 rows x 176 columns]

# %%
hero_name.iloc[0]
hero_name.iloc[1:3] # Inclusive, Exclusive
# Out:
#             gender eye color               race hair color  height  \
# name
# Abomination   Male     green  Human / Radiation    No Hair     203
# Abraxas       Male      blue      Cosmic Entity      Black     -99
#
#                  publisher alignment  weight   hero names  agility  ...  \
# name                                                                ...
# Abomination  Marvel Comics       bad     441  Abomination    False  ...
# Abraxas      Marvel Comics       bad     -99      Abraxas    False  ...
#
#              web creation  reality warping  odin force  symbiote costume  \
# name
# Abomination         False            False       False             False
# Abraxas             False            False       False             False
#
#              speed force  phoenix force  molecular dissipation  vision - cryo  \
# name
# Abomination        False          False                  False          False
# Abraxas            False          False                  False          False
#
#              omnipresent  omniscient
# name
# Abomination        False       False
# Abraxas            False       False
#
# [2 rows x 176 columns]

# %%
hero_name['alignment'] == 'bad' # you can use == on the selection to filter
# Out:
# name
# A-Bomb             False
# Abomination         True
# Abraxas             True
# Absorbing Man       True
# Agent Bob          False
#                    ...
# X-23               False
# X-Man              False
# Yellowjacket       False
# Yellowjacket II    False
# Ymir               False
# Name: alignment, Length: 341, dtype: bool

# %%
hero_name['alignment'] == 'bad' # you can use == on the selection to filter
# Out:
# name
# A-Bomb             False
# Abomination         True
# Abraxas             True
# Absorbing Man       True
# Agent Bob          False
#                    ...
# X-23               False
# X-Man              False
# Yellowjacket       False
# Yellowjacket II    False
# Ymir               False
# Name: alignment, Length: 341, dtype: bool

# %%
hero_name[hero_name['alignment'] == 'bad'] # you can use == on the selection to filter
# Out:
#               gender eye color               race hair color  height  \
# name
# Abomination     Male     green  Human / Radiation    No Hair     203
# Abraxas         Male      blue      Cosmic Entity      Black     -99
# Absorbing Man   Male      blue              Human    No Hair     193
# Air-Walker      Male      blue                  -      White     188
# Ajax            Male     brown             Cyborg      Black     193
# ...              ...       ...                ...        ...     ...
# Venom II        Male     brown                  -      Black     175
# Venom III       Male     brown           Symbiote      Brown     229
# Vulture         Male     brown              Human    No Hair     180
# Walrus          Male      blue              Human      Black     183
# Weapon XI       Male         -                  -          -     -99
#
#                    publisher alignment  weight     hero names  agility  ...  \
# name                                                                    ...
# Abomination    Marvel Comics       bad     441    Abomination    False  ...
# Abraxas        Marvel Comics       bad     -99        Abraxas    False  ...
# Absorbing Man  Marvel Comics       bad     122  Absorbing Man    False  ...
# Air-Walker     Marvel Comics       bad     108     Air-Walker    False  ...
# Ajax           Marvel Comics       bad      90           Ajax     True  ...
# ...                      ...       ...     ...            ...      ...  ...
# Venom II       Marvel Comics       bad      50       Venom II     True  ...
# Venom III      Marvel Comics       bad     334      Venom III     True  ...
# Vulture        Marvel Comics       bad      79        Vulture     True  ...
# Walrus         Marvel Comics       bad     162         Walrus    False  ...
# Weapon XI      Marvel Comics       bad     -99      Weapon XI     True  ...
#
#                web creation  reality warping  odin force  symbiote costume  \
# name
# Abomination           False            False       False             False
# Abraxas               False            False       False             False
# Absorbing Man         False            False       False             False
# Air-Walker            False            False       False             False
# Ajax                  False            False       False             False
# ...                     ...              ...         ...               ...
# Venom II              False            False       False             False
# Venom III             False            False       False              True
# Vulture               False            False       False             False
# Walrus                False            False       False             False
# Weapon XI             False            False       False             False
#
#                speed force  phoenix force  molecular dissipation  \
# name
# Abomination          False          False                  False
# Abraxas              False          False                  False
# Absorbing Man        False          False                  False
# Air-Walker           False          False                  False
# Ajax                 False          False                  False
# ...                    ...            ...                    ...
# Venom II             False          False                  False
# Venom III            False          False                  False
# Vulture              False          False                  False
# Walrus               False          False                  False
# Weapon XI            False          False                  False
#
#                vision - cryo  omnipresent  omniscient
# name
# Abomination            False        False       False
# Abraxas                False        False       False
# Absorbing Man          False        False       False
# Air-Walker             False        False       False
# Ajax                   False        False       False
# ...                      ...          ...         ...
# Venom II               False        False       False
# Venom III              False        False       False
# Vulture                False        False       False
# Walrus                 False        False       False
# Weapon XI              False        False       False
#
# [107 rows x 176 columns]

# %%
hero_name.loc[hero_name['alignment'] == 'bad']
 # you can use == on the selection to filter
# Out:
#               gender eye color               race hair color  height  \
# name
# Abomination     Male     green  Human / Radiation    No Hair     203
# Abraxas         Male      blue      Cosmic Entity      Black     -99
# Absorbing Man   Male      blue              Human    No Hair     193
# Air-Walker      Male      blue                  -      White     188
# Ajax            Male     brown             Cyborg      Black     193
# ...              ...       ...                ...        ...     ...
# Venom II        Male     brown                  -      Black     175
# Venom III       Male     brown           Symbiote      Brown     229
# Vulture         Male     brown              Human    No Hair     180
# Walrus          Male      blue              Human      Black     183
# Weapon XI       Male         -                  -          -     -99
#
#                    publisher alignment  weight     hero names  agility  ...  \
# name                                                                    ...
# Abomination    Marvel Comics       bad     441    Abomination    False  ...
# Abraxas        Marvel Comics       bad     -99        Abraxas    False  ...
# Absorbing Man  Marvel Comics       bad     122  Absorbing Man    False  ...
# Air-Walker     Marvel Comics       bad     108     Air-Walker    False  ...
# Ajax           Marvel Comics       bad      90           Ajax     True  ...
# ...                      ...       ...     ...            ...      ...  ...
# Venom II       Marvel Comics       bad      50       Venom II     True  ...
# Venom III      Marvel Comics       bad     334      Venom III     True  ...
# Vulture        Marvel Comics       bad      79        Vulture     True  ...
# Walrus         Marvel Comics       bad     162         Walrus    False  ...
# Weapon XI      Marvel Comics       bad     -99      Weapon XI     True  ...
#
#                web creation  reality warping  odin force  symbiote costume  \
# name
# Abomination           False            False       False             False
# Abraxas               False            False       False             False
# Absorbing Man         False            False       False             False
# Air-Walker            False            False       False             False
# Ajax                  False            False       False             False
# ...                     ...              ...         ...               ...
# Venom II              False            False       False             False
# Venom III             False            False       False              True
# Vulture               False            False       False             False
# Walrus                False            False       False             False
# Weapon XI             False            False       False             False
#
#                speed force  phoenix force  molecular dissipation  \
# name
# Abomination          False          False                  False
# Abraxas              False          False                  False
# Absorbing Man        False          False                  False
# Air-Walker           False          False                  False
# Ajax                 False          False                  False
# ...                    ...            ...                    ...
# Venom II             False          False                  False
# Venom III            False          False                  False
# Vulture              False          False                  False
# Walrus               False          False                  False
# Weapon XI            False          False                  False
#
#                vision - cryo  omnipresent  omniscient
# name
# Abomination            False        False       False
# Abraxas                False        False       False
# Absorbing Man          False        False       False
# Air-Walker             False        False       False
# Ajax                   False        False       False
# ...                      ...          ...         ...
# Venom II               False        False       False
# Venom III              False        False       False
# Vulture                False        False       False
# Walrus                 False        False       False
# Weapon XI              False        False       False
#
# [107 rows x 176 columns]

# %%
# The next one on iloc failed because we are returning (labels,values) not values
# hero_name.iloc[hero_name['alignment'] == 'bad']
hero_name.iloc[(hero_name['alignment'] == 'bad').values]
# Out:
#               gender eye color               race hair color  height  \
# name
# Abomination     Male     green  Human / Radiation    No Hair     203
# Abraxas         Male      blue      Cosmic Entity      Black     -99
# Absorbing Man   Male      blue              Human    No Hair     193
# Air-Walker      Male      blue                  -      White     188
# Ajax            Male     brown             Cyborg      Black     193
# ...              ...       ...                ...        ...     ...
# Venom II        Male     brown                  -      Black     175
# Venom III       Male     brown           Symbiote      Brown     229
# Vulture         Male     brown              Human    No Hair     180
# Walrus          Male      blue              Human      Black     183
# Weapon XI       Male         -                  -          -     -99
#
#                    publisher alignment  weight     hero names  agility  ...  \
# name                                                                    ...
# Abomination    Marvel Comics       bad     441    Abomination    False  ...
# Abraxas        Marvel Comics       bad     -99        Abraxas    False  ...
# Absorbing Man  Marvel Comics       bad     122  Absorbing Man    False  ...
# Air-Walker     Marvel Comics       bad     108     Air-Walker    False  ...
# Ajax           Marvel Comics       bad      90           Ajax     True  ...
# ...                      ...       ...     ...            ...      ...  ...
# Venom II       Marvel Comics       bad      50       Venom II     True  ...
# Venom III      Marvel Comics       bad     334      Venom III     True  ...
# Vulture        Marvel Comics       bad      79        Vulture     True  ...
# Walrus         Marvel Comics       bad     162         Walrus    False  ...
# Weapon XI      Marvel Comics       bad     -99      Weapon XI     True  ...
#
#                web creation  reality warping  odin force  symbiote costume  \
# name
# Abomination           False            False       False             False
# Abraxas               False            False       False             False
# Absorbing Man         False            False       False             False
# Air-Walker            False            False       False             False
# Ajax                  False            False       False             False
# ...                     ...              ...         ...               ...
# Venom II              False            False       False             False
# Venom III             False            False       False              True
# Vulture               False            False       False             False
# Walrus                False            False       False             False
# Weapon XI             False            False       False             False
#
#                speed force  phoenix force  molecular dissipation  \
# name
# Abomination          False          False                  False
# Abraxas              False          False                  False
# Absorbing Man        False          False                  False
# Air-Walker           False          False                  False
# Ajax                 False          False                  False
# ...                    ...            ...                    ...
# Venom II             False          False                  False
# Venom III            False          False                  False
# Vulture              False          False                  False
# Walrus               False          False                  False
# Weapon XI            False          False                  False
#
#                vision - cryo  omnipresent  omniscient
# name
# Abomination            False        False       False
# Abraxas                False        False       False
# Absorbing Man          False        False       False
# Air-Walker             False        False       False
# Ajax                   False        False       False
# ...                      ...          ...         ...
# Venom II               False        False       False
# Venom III              False        False       False
# Vulture                False        False       False
# Walrus                 False        False       False
# Weapon XI              False        False       False
#
# [107 rows x 176 columns]

# %%
hero_name[(hero_name['alignment'] == 'bad') & (hero_name['height'] >= 200)] # you can use == on the selection to filter
# It must use bitwise operators (& | ~ ) and parenthesis
# Out:
#                 gender eye color               race hair color  height  \
# name
# Abomination       Male     green  Human / Radiation    No Hair     203
# Apocalypse        Male       red             Mutant      Black     213
# Bloodaxe        Female      blue              Human      Brown     218
# Doctor Doom       Male     brown              Human      Brown     201
# Doctor Doom II    Male     brown                  -      Brown     201
# Frenzy          Female     brown                  -      Black     211
# Hela            Female     green          Asgardian      Black     213
# Lizard            Male       red              Human    No Hair     203
# MODOK             Male     white             Cyborg     Brownn     366
# Onslaught         Male       red             Mutant    No Hair     305
# Scorpion          Male     brown              Human      Brown     211
# Thanos            Male       red            Eternal    No Hair     201
# Ultron            Male       red            Android          -     206
# Venom III         Male     brown           Symbiote      Brown     229
#
#                     publisher alignment  weight      hero names  agility  ...  \
# name                                                                      ...
# Abomination     Marvel Comics       bad     441     Abomination    False  ...
# Apocalypse      Marvel Comics       bad     135      Apocalypse     True  ...
# Bloodaxe        Marvel Comics       bad     495        Bloodaxe     True  ...
# Doctor Doom     Marvel Comics       bad     187     Doctor Doom    False  ...
# Doctor Doom II  Marvel Comics       bad     132  Doctor Doom II    False  ...
# Frenzy          Marvel Comics       bad     104          Frenzy    False  ...
# Hela            Marvel Comics       bad     225            Hela     True  ...
# Lizard          Marvel Comics       bad     230          Lizard    False  ...
# MODOK           Marvel Comics       bad     338           MODOK     True  ...
# Onslaught       Marvel Comics       bad     405       Onslaught    False  ...
# Scorpion        Marvel Comics       bad     310        Scorpion     True  ...
# Thanos          Marvel Comics       bad     443          Thanos     True  ...
# Ultron          Marvel Comics       bad     331          Ultron     True  ...
# Venom III       Marvel Comics       bad     334       Venom III     True  ...
#
#                 web creation  reality warping  odin force  symbiote costume  \
# name
# Abomination            False            False       False             False
# Apocalypse             False            False       False             False
# Bloodaxe               False            False       False             False
# Doctor Doom            False            False       False             False
# Doctor Doom II         False            False       False             False
# Frenzy                 False            False       False             False
# Hela                   False            False       False             False
# Lizard                 False            False       False             False
# MODOK                  False            False       False             False
# Onslaught              False             True       False             False
# Scorpion               False            False       False             False
# Thanos                 False             True       False             False
# Ultron                 False            False       False             False
# Venom III              False            False       False              True
#
#                 speed force  phoenix force  molecular dissipation  \
# name
# Abomination           False          False                  False
# Apocalypse            False          False                  False
# Bloodaxe              False          False                  False
# Doctor Doom           False          False                  False
# Doctor Doom II        False          False                  False
# Frenzy                False          False                  False
# Hela                  False          False                  False
# Lizard                False          False                  False
# MODOK                 False          False                  False
# Onslaught             False          False                  False
# Scorpion              False          False                  False
# Thanos                False          False                  False
# Ultron                False          False                  False
# Venom III             False          False                  False
#
#                 vision - cryo  omnipresent  omniscient
# name
# Abomination             False        False       False
# Apocalypse              False        False       False
# Bloodaxe                False        False       False
# Doctor Doom             False        False       False
# Doctor Doom II          False        False       False
# Frenzy                  False        False       False
# Hela                    False        False       False
# Lizard                  False        False       False
# MODOK                   False        False       False
# Onslaught               False        False       False
# Scorpion                False        False       False
# Thanos                  False        False       False
# Ultron                  False        False       False
# Venom III               False        False       False
#
# [14 rows x 176 columns]

# %%
hero_name[hero_name['alignment'].isin(['bad'])] # you can use == on the selection to filter
# Out:
#               gender eye color               race hair color  height  \
# name
# Abomination     Male     green  Human / Radiation    No Hair     203
# Abraxas         Male      blue      Cosmic Entity      Black     -99
# Absorbing Man   Male      blue              Human    No Hair     193
# Air-Walker      Male      blue                  -      White     188
# Ajax            Male     brown             Cyborg      Black     193
# ...              ...       ...                ...        ...     ...
# Venom II        Male     brown                  -      Black     175
# Venom III       Male     brown           Symbiote      Brown     229
# Vulture         Male     brown              Human    No Hair     180
# Walrus          Male      blue              Human      Black     183
# Weapon XI       Male         -                  -          -     -99
#
#                    publisher alignment  weight     hero names  agility  ...  \
# name                                                                    ...
# Abomination    Marvel Comics       bad     441    Abomination    False  ...
# Abraxas        Marvel Comics       bad     -99        Abraxas    False  ...
# Absorbing Man  Marvel Comics       bad     122  Absorbing Man    False  ...
# Air-Walker     Marvel Comics       bad     108     Air-Walker    False  ...
# Ajax           Marvel Comics       bad      90           Ajax     True  ...
# ...                      ...       ...     ...            ...      ...  ...
# Venom II       Marvel Comics       bad      50       Venom II     True  ...
# Venom III      Marvel Comics       bad     334      Venom III     True  ...
# Vulture        Marvel Comics       bad      79        Vulture     True  ...
# Walrus         Marvel Comics       bad     162         Walrus    False  ...
# Weapon XI      Marvel Comics       bad     -99      Weapon XI     True  ...
#
#                web creation  reality warping  odin force  symbiote costume  \
# name
# Abomination           False            False       False             False
# Abraxas               False            False       False             False
# Absorbing Man         False            False       False             False
# Air-Walker            False            False       False             False
# Ajax                  False            False       False             False
# ...                     ...              ...         ...               ...
# Venom II              False            False       False             False
# Venom III             False            False       False              True
# Vulture               False            False       False             False
# Walrus                False            False       False             False
# Weapon XI             False            False       False             False
#
#                speed force  phoenix force  molecular dissipation  \
# name
# Abomination          False          False                  False
# Abraxas              False          False                  False
# Absorbing Man        False          False                  False
# Air-Walker           False          False                  False
# Ajax                 False          False                  False
# ...                    ...            ...                    ...
# Venom II             False          False                  False
# Venom III            False          False                  False
# Vulture              False          False                  False
# Walrus               False          False                  False
# Weapon XI            False          False                  False
#
#                vision - cryo  omnipresent  omniscient
# name
# Abomination            False        False       False
# Abraxas                False        False       False
# Absorbing Man          False        False       False
# Air-Walker             False        False       False
# Ajax                   False        False       False
# ...                      ...          ...         ...
# Venom II               False        False       False
# Venom III              False        False       False
# Vulture                False        False       False
# Walrus                 False        False       False
# Weapon XI              False        False       False
#
# [107 rows x 176 columns]

# %%
#df.loc[labels, cols] => Select using labels for rows and cols
# #df.iloc => Select using positions
hero.loc[0,:]
hero.loc[[0,3],:]
hero.loc[[0,3]]
hero.loc[0:3]
# Out:
#             name gender eye color               race hair color  height  \
# 0         A-Bomb   Male    yellow              Human    No Hair     203
# 1    Abomination   Male     green  Human / Radiation    No Hair     203
# 2        Abraxas   Male      blue      Cosmic Entity      Black     -99
# 3  Absorbing Man   Male      blue              Human    No Hair     193
#
#        publisher alignment  weight     hero names  ...  web creation  \
# 0  Marvel Comics      good     441         A-Bomb  ...         False
# 1  Marvel Comics       bad     441    Abomination  ...         False
# 2  Marvel Comics       bad     -99        Abraxas  ...         False
# 3  Marvel Comics       bad     122  Absorbing Man  ...         False
#
#    reality warping  odin force  symbiote costume  speed force  phoenix force  \
# 0            False       False             False        False          False
# 1            False       False             False        False          False
# 2            False       False             False        False          False
# 3            False       False             False        False          False
#
#    molecular dissipation  vision - cryo  omnipresent  omniscient
# 0                  False          False        False       False
# 1                  False          False        False       False
# 2                  False          False        False       False
# 3                  False          False        False       False
#
# [4 rows x 177 columns]

# %%
hero.loc[0,"race"]
# Out:
# 'Human'

# %%
hero.iloc[0,3]
# Out:
# 'Human'

# %%
hero.loc[2:4,"race":"height"]
hero.loc[2:4,["race", "hair color","height"]]
#Using iloc - Notice the slice diff, last is exclusive in iloc
hero.iloc[2:5,3:6]
hero.iloc[[2,3,4,5],3:6]
hero.iloc[[2,3,4,5],[3,4,5]]
# Out:
#             race hair color  height
# 2  Cosmic Entity      Black     -99
# 3          Human    No Hair     193
# 4          Human      Brown     178
# 5              -          -     191

# %%
# Change Cell - "=" modify in place, no need to reassign 
hero.loc[2,'race'] = 'Unknown'
hero.loc[2,'race']
hero.iloc[2,3] = 'Human'
hero.iloc[2,3] 
hero.head()

# Modifying Col on certain value
hero.loc[hero['race']=='-', 'race' ] = 'Unknown' 
hero.loc[hero['race']=='Unknown']
# Out:
#                 name  gender eye color     race hair color  height  \
# 5         Agent Zero    Male         -  Unknown          -     191
# 6         Air-Walker    Male      blue  Unknown      White     188
# 9              Angel    Male      blue  Unknown      Blond     183
# 11   Angel Salvadore  Female     brown  Unknown      Black     163
# 12         Annihilus    Male     green  Unknown    No Hair     180
# ..               ...     ...       ...      ...        ...     ...
# 330          Watcher    Male         -  Unknown          -     -99
# 331        Weapon XI    Male         -  Unknown          -     -99
# 333        Wolfsbane  Female     green  Unknown     Auburn     366
# 335       Wonder Man    Male       red  Unknown      Black     188
# 337            X-Man    Male      blue  Unknown      Brown     175
#
#          publisher alignment  weight       hero names  ...  web creation  \
# 5    Marvel Comics      good     104       Agent Zero  ...         False
# 6    Marvel Comics       bad     108       Air-Walker  ...         False
# 9    Marvel Comics      good      68            Angel  ...         False
# 11   Marvel Comics      good      54  Angel Salvadore  ...         False
# 12   Marvel Comics       bad      90        Annihilus  ...         False
# ..             ...       ...     ...              ...  ...           ...
# 330  Marvel Comics      good     -99          Watcher  ...         False
# 331  Marvel Comics       bad     -99        Weapon XI  ...         False
# 333  Marvel Comics      good     473        Wolfsbane  ...         False
# 335  Marvel Comics      good     171       Wonder Man  ...         False
# 337  Marvel Comics      good      61            X-Man  ...         False
#
#      reality warping  odin force  symbiote costume  speed force  \
# 5              False       False             False        False
# 6              False       False             False        False
# 9              False       False             False        False
# 11             False       False             False        False
# 12             False       False             False        False
# ..               ...         ...               ...          ...
# 330            False       False             False        False
# 331            False       False             False        False
# 333            False       False             False        False
# 335            False       False             False        False
# 337            False       False             False        False
#
#      phoenix force  molecular dissipation  vision - cryo  omnipresent  \
# 5            False                  False          False        False
# 6            False                  False          False        False
# 9            False                  False          False        False
# 11           False                  False          False        False
# 12           False                  False          False        False
# ..             ...                    ...            ...          ...
# 330          False                  False          False        False
# 331          False                  False          False        False
# 333          False                  False          False        False
# 335          False                  False          False        False
# 337          False                  False          False        False
#
#      omniscient
# 5         False
# 6         False
# 9         False
# 11        False
# 12        False
# ..          ...
# 330       False
# 331       False
# 333       False
# 335       False
# 337       False
#
# [135 rows x 177 columns]

# %%
hero.loc[1000] = hero.iloc[3]
hero.tail()
# Out:
#                  name  gender eye color         race        hair color  \
# 337             X-Man    Male      blue      Unknown             Brown
# 338      Yellowjacket    Male      blue        Human             Blond
# 339   Yellowjacket II  Female      blue        Human  Strawberry Blond
# 340              Ymir    Male     white  Frost Giant           No Hair
# 1000    Absorbing Man    Male      blue        Human           No Hair
#
#       height      publisher alignment  weight       hero names  ...  \
# 337      175  Marvel Comics      good      61            X-Man  ...
# 338      183  Marvel Comics      good      83     Yellowjacket  ...
# 339      165  Marvel Comics      good      52  Yellowjacket II  ...
# 340      305  Marvel Comics      good     -99             Ymir  ...
# 1000     193  Marvel Comics       bad     122    Absorbing Man  ...
#
#       web creation  reality warping  odin force  symbiote costume  \
# 337          False            False       False             False
# 338          False            False       False             False
# 339          False            False       False             False
# 340          False            False       False             False
# 1000         False            False       False             False
#
#       speed force  phoenix force  molecular dissipation  vision - cryo  \
# 337         False          False                  False          False
# 338         False          False                  False          False
# 339         False          False                  False          False
# 340         False          False                  False          False
# 1000        False          False                  False          False
#
#       omnipresent  omniscient
# 337         False       False
# 338         False       False
# 339         False       False
# 340         False       False
# 1000        False       False
#
# [5 rows x 177 columns]

# %%
hero['height']=hero['height']*0.0328
hero.head()
# Out:
#             name gender eye color               race hair color  height  \
# 0         A-Bomb   Male    yellow              Human    No Hair  6.6584
# 1    Abomination   Male     green  Human / Radiation    No Hair  6.6584
# 2        Abraxas   Male      blue              Human      Black -3.2472
# 3  Absorbing Man   Male      blue              Human    No Hair  6.3304
# 4      Agent Bob   Male     brown              Human      Brown  5.8384
#
#        publisher alignment  weight     hero names  ...  web creation  \
# 0  Marvel Comics      good     441         A-Bomb  ...         False
# 1  Marvel Comics       bad     441    Abomination  ...         False
# 2  Marvel Comics       bad     -99        Abraxas  ...         False
# 3  Marvel Comics       bad     122  Absorbing Man  ...         False
# 4  Marvel Comics      good      81      Agent Bob  ...         False
#
#    reality warping  odin force  symbiote costume  speed force  phoenix force  \
# 0            False       False             False        False          False
# 1            False       False             False        False          False
# 2            False       False             False        False          False
# 3            False       False             False        False          False
# 4            False       False             False        False          False
#
#    molecular dissipation  vision - cryo  omnipresent  omniscient
# 0                  False          False        False       False
# 1                  False          False        False       False
# 2                  False          False        False       False
# 3                  False          False        False       False
# 4                  False          False        False       False
#
# [5 rows x 177 columns]

# %%
num_cols = hero.select_dtypes(include='number').columns
type(num_cols)
hero[num_cols]
# Out:
#        height  weight
# 0      6.6584     441
# 1      6.6584     441
# 2     -3.2472     -99
# 3      6.3304     122
# 4      5.8384      81
# ...       ...     ...
# 337    5.7400      61
# 338    6.0024      83
# 339    5.4120      52
# 340   10.0040     -99
# 1000   6.3304     122
#
# [342 rows x 2 columns]

# %%
type((hero['weight']/hero['height']/3.28)**2)
# Since it returns a Series it will use the index for assignment
# Using = uses the index of the Series to assign values 
hero['bmi']=(hero['weight']/hero['height']/3.28)**2
hero.head()
# Out:
#             name gender eye color               race hair color  height  \
# 0         A-Bomb   Male    yellow              Human    No Hair  6.6584
# 1    Abomination   Male     green  Human / Radiation    No Hair  6.6584
# 2        Abraxas   Male      blue              Human      Black -3.2472
# 3  Absorbing Man   Male      blue              Human    No Hair  6.3304
# 4      Agent Bob   Male     brown              Human      Brown  5.8384
#
#        publisher alignment  weight     hero names  ...  reality warping  \
# 0  Marvel Comics      good     441         A-Bomb  ...            False
# 1  Marvel Comics       bad     441    Abomination  ...            False
# 2  Marvel Comics       bad     -99        Abraxas  ...            False
# 3  Marvel Comics       bad     122  Absorbing Man  ...            False
# 4  Marvel Comics      good      81      Agent Bob  ...            False
#
#    odin force  symbiote costume  speed force  phoenix force  \
# 0       False             False        False          False
# 1       False             False        False          False
# 2       False             False        False          False
# 3       False             False        False          False
# 4       False             False        False          False
#
#    molecular dissipation  vision - cryo  omnipresent  omniscient         bmi
# 0                  False          False        False       False  407.746018
# 1                  False          False        False       False  407.746018
# 2                  False          False        False       False   86.398186
# 3                  False          False        False       False   34.523091
# 4                  False          False        False       False   17.891002
#
# [5 rows x 178 columns]

# %%
hero_copy = hero.copy()
hero_copy.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 342 entries, 0 to 1000
# Data columns (total 178 columns):
#  #    Column                        Dtype
# ---   ------                        -----
#  0    name                          object
#  1    gender                        object
#  2    eye color                     object
#  3    race                          object
#  4    hair color                    object
#  5    height                        float64
#  6    publisher                     object
#  7    alignment                     object
#  8    weight                        int64
#  9    hero names                    object
#  10   agility                       bool
#  11   accelerated healing           bool
#  12   lantern power ring            bool
#  13   dimensional awareness         bool
#  14   cold resistance               bool
#  15   durability                    bool
#  16   stealth                       bool
#  17   energy absorption             bool
#  18   flight                        bool
#  19   danger sense                  bool
#  20   underwater breathing          bool
#  21   marksmanship                  bool
#  22   weapons master                bool
#  23   power augmentation            bool
#  24   animal attributes             bool
#  25   longevity                     bool
#  26   intelligence                  bool
#  27   super strength                bool
#  28   cryokinesis                   bool
#  29   telepathy                     bool
#  30   energy armor                  bool
#  31   energy blasts                 bool
#  32   duplication                   bool
#  33   size changing                 bool
#  34   density control               bool
#  35   stamina                       bool
#  36   astral travel                 bool
#  37   audio control                 bool
#  38   dexterity                     bool
#  39   omnitrix                      bool
#  40   super speed                   bool
#  41   possession                    bool
#  42   animal oriented powers        bool
#  43   weapon-based powers           bool
#  44   electrokinesis                bool
#  45   darkforce manipulation        bool
#  46   death touch                   bool
#  47   teleportation                 bool
#  48   enhanced senses               bool
#  49   telekinesis                   bool
#  50   energy beams                  bool
#  51   magic                         bool
#  52   hyperkinesis                  bool
#  53   jump                          bool
#  54   clairvoyance                  bool
#  55   dimensional travel            bool
#  56   power sense                   bool
#  57   shapeshifting                 bool
#  58   peak human condition          bool
#  59   immortality                   bool
#  60   camouflage                    bool
#  61   element control               bool
#  62   phasing                       bool
#  63   astral projection             bool
#  64   electrical transport          bool
#  65   fire control                  bool
#  66   projection                    bool
#  67   summoning                     bool
#  68   enhanced memory               bool
#  69   reflexes                      bool
#  70   invulnerability               bool
#  71   energy constructs             bool
#  72   force fields                  bool
#  73   self-sustenance               bool
#  74   anti-gravity                  bool
#  75   empathy                       bool
#  76   power nullifier               bool
#  77   radiation control             bool
#  78   psionic powers                bool
#  79   elasticity                    bool
#  80   substance secretion           bool
#  81   elemental transmogrification  bool
#  82   technopath/cyberpath          bool
#  83   photographic reflexes         bool
#  84   seismic power                 bool
#  85   animation                     bool
#  86   precognition                  bool
#  87   mind control                  bool
#  88   fire resistance               bool
#  89   power absorption              bool
#  90   enhanced hearing              bool
#  91   nova force                    bool
#  92   insanity                      bool
#  93   hypnokinesis                  bool
#  94   animal control                bool
#  95   natural armor                 bool
#  96   intangibility                 bool
#  97   enhanced sight                bool
#  98   molecular manipulation        bool
#  99   heat generation               bool
#  100  adaptation                    bool
#  101  gliding                       bool
#  102  power suit                    bool
#  103  mind blast                    bool
#  104  probability manipulation      bool
#  105  gravity control               bool
#  106  regeneration                  bool
#  107  light control                 bool
#  108  echolocation                  bool
#  109  levitation                    bool
#  110  toxin and disease control     bool
#  111  banish                        bool
#  112  energy manipulation           bool
#  113  heat resistance               bool
#  114  natural weapons               bool
#  115  time travel                   bool
#  116  enhanced smell                bool
#  117  illusions                     bool
#  118  thirstokinesis                bool
#  119  hair manipulation             bool
#  120  illumination                  bool
#  121  omnipotent                    bool
#  122  cloaking                      bool
#  123  changing armor                bool
#  124  power cosmic                  bool
#  125  biokinesis                    bool
#  126  water control                 bool
#  127  radiation immunity            bool
#  128  vision - telescopic           bool
#  129  toxin and disease resistance  bool
#  130  spatial awareness             bool
#  131  energy resistance             bool
#  132  telepathy resistance          bool
#  133  molecular combustion          bool
#  134  omnilingualism                bool
#  135  portal creation               bool
#  136  magnetism                     bool
#  137  mind control resistance       bool
#  138  plant control                 bool
#  139  sonar                         bool
#  140  sonic scream                  bool
#  141  time manipulation             bool
#  142  enhanced touch                bool
#  143  magic resistance              bool
#  144  invisibility                  bool
#  145  sub-mariner                   bool
#  146  radiation absorption          bool
#  147  intuitive aptitude            bool
#  148  vision - microscopic          bool
#  149  melting                       bool
#  150  wind control                  bool
#  151  super breath                  bool
#  152  wallcrawling                  bool
#  153  vision - night                bool
#  154  vision - infrared             bool
#  155  grim reaping                  bool
#  156  matter absorption             bool
#  157  the force                     bool
#  158  resurrection                  bool
#  159  terrakinesis                  bool
#  160  vision - heat                 bool
#  161  vitakinesis                   bool
#  162  radar sense                   bool
#  163  qwardian power ring           bool
#  164  weather control               bool
#  165  vision - x-ray                bool
#  166  vision - thermal              bool
#  167  web creation                  bool
#  168  reality warping               bool
#  169  odin force                    bool
#  170  symbiote costume              bool
#  171  speed force                   bool
#  172  phoenix force                 bool
#  173  molecular dissipation         bool
#  174  vision - cryo                 bool
#  175  omnipresent                   bool
#  176  omniscient                    bool
#  177  bmi                           float64
# dtypes: bool(167), float64(2), int64(1), object(8)
# memory usage: 87.8+ KB

# %%
hero.sort_values(by="race")
# Viewing the largest or smallest values
hero.nlargest(n=10,columns="height")['height']
# Out:
# 117    31.9800
# 125    28.7328
# 139    22.9928
# 207    12.0048
# 333    12.0048
# 231    10.0040
# 254    10.0040
# 340    10.0040
# 169     9.4136
# 150     8.0032
# Name: height, dtype: float64
